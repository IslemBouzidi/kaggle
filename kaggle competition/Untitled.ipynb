# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train.csv')
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg  \
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000  \
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...  \
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.dropna(subset=['Electrical'], inplace=True)#

# %%
for column in df.columns:
    percantage_missing = np.mean(df[column].isnull())
    print('{} :{} --> {}%'.format(column,df.dtypes[column],percantage_missing))
# Out:
# Id :int64 --> 0.0%
# MSSubClass :int64 --> 0.0%
# MSZoning :object --> 0.0%
# LotFrontage :float64 --> 0.17751884852638794%
# LotArea :int64 --> 0.0%
# Street :object --> 0.0%
# Alley :object --> 0.9376285126799178%
# LotShape :object --> 0.0%
# LandContour :object --> 0.0%
# Utilities :object --> 0.0%
# LotConfig :object --> 0.0%
# LandSlope :object --> 0.0%
# Neighborhood :object --> 0.0%
# Condition1 :object --> 0.0%
# Condition2 :object --> 0.0%
# BldgType :object --> 0.0%
# HouseStyle :object --> 0.0%
# OverallQual :int64 --> 0.0%
# OverallCond :int64 --> 0.0%
# YearBuilt :int64 --> 0.0%
# YearRemodAdd :int64 --> 0.0%
# RoofStyle :object --> 0.0%
# RoofMatl :object --> 0.0%
# Exterior1st :object --> 0.0%
# Exterior2nd :object --> 0.0%
# MasVnrType :object --> 0.5969842357779301%
# MasVnrArea :float64 --> 0.0054832076764907475%
# ExterQual :object --> 0.0%
# ExterCond :object --> 0.0%
# Foundation :object --> 0.0%
# BsmtQual :object --> 0.025359835503769704%
# ...

# %%
# columns to be dropped due to high None values:
#Alley, FireplaceQu, PoolQC, Fence, MiscFeature

# %%
houses= df.drop(['Alley','FireplaceQu','PoolQC','Fence','MiscFeature',
         'MasVnrType','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1',
        'BsmtFinType2','GarageType','GarageFinish','GarageQual','GarageCond',
        ], axis=1)

# %%
houses
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape
# 0        1          60       RL         65.0     8450   Pave      Reg  \
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch
# ...

# %%
for column in houses.columns:
    percantage_missing = np.mean(houses[column].isnull())
    print('{} :{} --> {}%'.format(column,houses.dtypes[column],percantage_missing))
# Out:
# Id :int64 --> 0.0%
# MSSubClass :int64 --> 0.0%
# MSZoning :object --> 0.0%
# LotFrontage :float64 --> 0.17751884852638794%
# LotArea :int64 --> 0.0%
# Street :object --> 0.0%
# LotShape :object --> 0.0%
# LandContour :object --> 0.0%
# Utilities :object --> 0.0%
# LotConfig :object --> 0.0%
# LandSlope :object --> 0.0%
# Neighborhood :object --> 0.0%
# Condition1 :object --> 0.0%
# Condition2 :object --> 0.0%
# BldgType :object --> 0.0%
# HouseStyle :object --> 0.0%
# OverallQual :int64 --> 0.0%
# OverallCond :int64 --> 0.0%
# YearBuilt :int64 --> 0.0%
# YearRemodAdd :int64 --> 0.0%
# RoofStyle :object --> 0.0%
# RoofMatl :object --> 0.0%
# Exterior1st :object --> 0.0%
# Exterior2nd :object --> 0.0%
# MasVnrArea :float64 --> 0.0054832076764907475%
# ExterQual :object --> 0.0%
# ExterCond :object --> 0.0%
# Foundation :object --> 0.0%
# BsmtFinSF1 :int64 --> 0.0%
# BsmtFinSF2 :int64 --> 0.0%
# BsmtUnfSF :int64 --> 0.0%
# TotalBsmtSF :int64 --> 0.0%
# Heating :object --> 0.0%
# ...

# %%
df_filled = houses.fillna(houses['GarageYrBlt'].mean())
df_filled = houses.fillna(houses['LotFrontage'].mean())
df_filled = houses.fillna(houses['MasVnrArea'].mean())

# %%
df_dropped = df_filled.dropna()

# %%
df_dropped
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape
# 0        1          60       RL         65.0     8450   Pave      Reg  \
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch
# ...

# %%
df_dropped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1459 entries, 0 to 1459
# Data columns (total 66 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1459 non-null   object
#  3   LotFrontage    1459 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   LotShape       1459 non-null   object
#  7   LandContour    1459 non-null   object
#  8   Utilities      1459 non-null   object
#  9   LotConfig      1459 non-null   object
#  10  LandSlope      1459 non-null   object
#  11  Neighborhood   1459 non-null   object
#  12  Condition1     1459 non-null   object
#  13  Condition2     1459 non-null   object
#  14  BldgType       1459 non-null   object
#  15  HouseStyle     1459 non-null   object
#  16  OverallQual    1459 non-null   int64
# ...

# %%
# the data now is clean:
# we will change the non-numerical values to numerical using sktlearn

# %%
train= df_dropped

# %%
from sklearn import preprocessing


object_data = train.select_dtypes(include=['object'])
lebel = preprocessing.LabelEncoder()
for i in range(object_data.shape[1]) :
    object_data.iloc[:,i]= lebel.fit_transform(object_data.iloc[:,i])

# %%
# The fucking data is clean and labeled

# %%
train_non_object = train.select_dtypes(exclude=['object']) 
train = pd.concat([object_data,train_non_object],axis=1)

# %%
train
# Out:
#      MSZoning Street LotShape LandContour Utilities LotConfig LandSlope
# 0           3      1        3           3         0         4         0  \
# 1           3      1        3           3         0         2         0
# 2           3      1        0           3         0         4         0
# 3           3      1        0           3         0         0         0
# 4           3      1        0           3         0         2         0
# ...       ...    ...      ...         ...       ...       ...       ...
# 1455        3      1        3           3         0         4         0
# 1456        3      1        3           3         0         4         0
# 1457        3      1        3           3         0         4         0
# 1458        3      1        3           3         0         4         0
# 1459        3      1        3           3         0         4         0
#
#      Neighborhood Condition1 Condition2  ... WoodDeckSF OpenPorchSF
# ...

# %%
corr= train.corr()
corr
# Out:
#              MSZoning    Street  LotShape  LandContour  Utilities  LotConfig
# MSZoning     1.000000  0.087656  0.061923    -0.017845  -0.001193  -0.009877  \
# Street       0.087656  1.000000 -0.010259     0.115985   0.001683   0.013935
# LotShape     0.061923 -0.010259  1.000000     0.085292  -0.036094   0.220861
# LandContour -0.017845  0.115985  0.085292     1.000000   0.008244  -0.025662
# Utilities   -0.001193  0.001683 -0.036094     0.008244   1.000000  -0.032583
# ...               ...       ...       ...          ...        ...        ...
# PoolArea    -0.003130  0.004416 -0.020019    -0.013084  -0.001800  -0.046775
# MiscVal      0.009290 -0.022729 -0.042024     0.020932  -0.002297  -0.018393
# MoSold      -0.031514  0.003712 -0.033212    -0.011494  -0.051565   0.019109
# YrSold      -0.020623 -0.025050  0.036384     0.020478   0.023355  -0.006051
# SalePrice   -0.166879  0.041043 -0.255545     0.015490  -0.014317  -0.067335
#
# ...

# %%
saleprice_corr = pd.DataFrame(corr['SalePrice'].sort_values(ascending=False))
saleprice_corr.head(20)
# Out:
#               SalePrice
# SalePrice      1.000000
# OverallQual    0.791069
# GrLivArea      0.708618
# GarageCars     0.640473
# GarageArea     0.623423
# TotalBsmtSF    0.613905
# 1stFlrSF       0.605968
# FullBath       0.560881
# TotRmsAbvGrd   0.533779
# YearBuilt      0.523273
# YearRemodAdd   0.507430
# MasVnrArea     0.475235
# Fireplaces     0.466968
# BsmtFinSF1     0.386436
# Foundation     0.382671
# WoodDeckSF     0.324422
# 2ndFlrSF       0.319464
# OpenPorchSF    0.315831
# LotFrontage    0.291144
# HalfBath       0.284400

# %%
# THE Columns that we will be using 
top_correlated_columns = corr['SalePrice'].nlargest(20).index.tolist()

# %%
top_correlated_columns= top_correlated_columns

# %%
least_correlated_columns = corr['SalePrice'].nsmallest(3).index.tolist()
least_correlated_columns
# Out:
# ['ExterQual', 'KitchenQual', 'HeatingQC']

# %%
all_correlated_columns = top_correlated_columns + least_correlated_columns
all_correlated_columns
''' 
OverallQual: Overall material and finish quality
LotFrontage: Linear feet of street connected to property
GrLivArea: Above grade (ground) living area square feet
GarageCars: Size of garage in car capacity
GarageArea: Size of garage in square feet
TotalBsmtSF: Total square feet of basement area
1stFlrSF: First Floor square feet
FullBath: Full bathrooms above grade
TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
YearBuilt: Original construction date
YearRemodAdd: Remodel date
MasVnrArea: Masonry veneer area in square feet
Fireplaces: Number of fireplaces
BsmtFinSF1: Type 1 finished square feet
Foundation: Type of foundation
WoodDeckSF: Wood deck area in square feet
2ndFlrSF: Second floor square feet
OpenPorchSF: Open porch area in square feet
LotFrontage: Linear feet of street connected to property
HalfBath: Half baths above grade
ExterQual: Exterior material quality
KitchenQual: Kitchen quality
HeatingQC: Heating quality and condition
'''
# Out:
# ' \nOverallQual: Overall material and finish quality\nLotFrontage: Linear feet of street connected to property\nGrLivArea: Above grade (ground) living area square feet\nGarageCars: Size of garage in car capacity\nGarageArea: Size of garage in square feet\nTotalBsmtSF: Total square feet of basement area\n1stFlrSF: First Floor square feet\nFullBath: Full bathrooms above grade\nTotRmsAbvGrd: Total rooms above grade (does not include bathrooms)\nYearBuilt: Original construction date\nYearRemodAdd: Remodel date\nMasVnrArea: Masonry veneer area in square feet\nFireplaces: Number of fireplaces\nBsmtFinSF1: Type 1 finished square feet\nFoundation: Type of foundation\nWoodDeckSF: Wood deck area in square feet\n2ndFlrSF: Second floor square feet\nOpenPorchSF: Open porch area in square feet\nLotFrontage: Linear feet of street connected to property\nHalfBath: Half baths above grade\nExterQual: Exterior material quality\nKitchenQual: Kitchen quality\nHeatingQC: Heating quality and condition\n'

# %%
features= all_correlated_columns

# %%
train= train[features]

# %%
train
# Out:
#       SalePrice  OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF
# 0        208500            7       1710           2         548          856  \
# 1        181500            6       1262           2         460         1262
# 2        223500            7       1786           2         608          920
# 3        140000            7       1717           3         642          756
# 4        250000            8       2198           3         836         1145
# ...         ...          ...        ...         ...         ...          ...
# 1455     175000            6       1647           2         460          953
# 1456     210000            6       2073           2         500         1542
# 1457     266500            7       2340           1         252         1152
# 1458     142125            5       1078           1         240         1078
# 1459     147500            5       1256           1         276         1256
#
# ...

# %%
train.hist(figsize=(30,25),bins=10,edgecolor='black',color='lightblue')

plt.show()# Normal distribution

# %%
plt.scatter(train['OverallQual'],train['SalePrice'])

# %%
num_features = len(features[1:])
num_plots_per_row = 3
num_rows = num_features // num_plots_per_row + (num_features % num_plots_per_row > 0)

fig, axs = plt.subplots(num_rows, num_plots_per_row, figsize=(15, 4*num_rows))
fig.subplots_adjust(hspace=0.5)  # Adjust the vertical spacing between subplots

for i, feature in enumerate(features[1:]):
    row = i // num_plots_per_row
    col = i % num_plots_per_row

    ax = axs[row, col]
    sns.scatterplot(x=feature, y="SalePrice", data=train, marker='o', ax=ax)
    ax.set_title(f"Scatter plot with regression line for {feature}")
    ax.set_xlabel(feature)
    ax.set_ylabel("SalePrice")

# Remove empty subplots if the number of features is not a multiple of num_plots_per_row
if num_features % num_plots_per_row != 0:
    for i in range(num_features, num_rows * num_plots_per_row):
        axs[-1, i % num_plots_per_row].axis('off')

plt.tight_layout()
plt.show()

# %%
df = train.drop(['HalfBath','ExterQual','HeatingQC','KitchenQual','Fireplaces','GarageCars','FullBath'], axis=1) # because their distribution

# %%
df= train

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression

# %%
features = df.columns
features
# Out:
# Index(['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
#        'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt',
#        'YearRemodAdd', 'MasVnrArea', 'Fireplaces', 'BsmtFinSF1', 'Foundation',
#        'WoodDeckSF', '2ndFlrSF', 'OpenPorchSF', 'LotFrontage', 'HalfBath',
#        'ExterQual', 'KitchenQual', 'HeatingQC'],
#       dtype='object')

# %%
features= [ 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
       'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt',
       'YearRemodAdd', 'MasVnrArea', 'Fireplaces', 'BsmtFinSF1', 'Foundation',
       'WoodDeckSF', '2ndFlrSF', 'OpenPorchSF', 'LotFrontage', 'HalfBath',
       'ExterQual', 'KitchenQual', 'HeatingQC']

# %%
x= df[features]
y = df['SalePrice']

# %%
model = LinearRegression()

k_folds = 5

cross_val = KFold(n_splits=k_folds, shuffle=True, random_state=2)

scores = cross_val_score(model, x, y, scoring='r2', cv=cross_val)

print("R-squared scores for each fold:", scores)

average_score = scores.mean()
print("Average R-squared score:", average_score)
# Out:
# R-squared scores for each fold: [0.85093913 0.75095369 0.67834147 0.87190059 0.84723046]
# Average R-squared score: 0.7998730670723628

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor()
k_folds = 5

cross_val = KFold(n_splits=k_folds, shuffle=True, random_state=2)

scores = cross_val_score(model, x, y, scoring='r2', cv=cross_val)

print("R-squared scores for each fold:", scores)

average_score = scores.mean()
print("Average R-squared score:", average_score)
# Out:
# R-squared scores for each fold: [0.86855497 0.8095264  0.86609555 0.89049105 0.87522149]
# Average R-squared score: 0.8619778942991246

# %%
xtr,xtst,ytr,ytst= train_test_split(df, target, test_size = 0.3)

# %%
mdl1 = linear_model.LinearRegression()
mdl1.fit(xtr,ytr)
# Out:
# LinearRegression()

# %%
mdl2 = linear_model.Ridge(alpha=0.5)
mdl2.fit(xtr,ytr)
# Out:
# Ridge(alpha=0.5)

# %%
ypred= mdl1.predict(xtst)
mse=mean_squared_error(ytst, ypred, squared= False)
r2= r2_score(ytst, ypred)
print(mse)
print(r2)
# Out:
# 5.5052060189492745e-11
# 1.0

# %%
ypred= mdl2.predict(xtst)
mse=mean_squared_error(ytst, ypred, squared= False)
r2= r2_score(ytst, ypred)
print(mse)
print(r2)
# Out:
# 2.84962079409917e-08
# 1.0

# %%
import statsmodels.api as sm

X = df[features]  # Replace with your actual predictor variables
y = df["SalePrice"]  # Replace with your actual response variable

model = sm.OLS(y, sm.add_constant(X))  # Assuming you want to fit an ordinary least squares (OLS) model
results = model.fit()

# Calculate the residuals
predicted_values = results.predict(sm.add_constant(X))
residuals = y - predicted_values

# Create a scatter plot of the residuals
plt.scatter(predicted_values, residuals)
plt.axhline(y=0, color='r', linestyle='--')
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 6
#       3 X = df[features]  # Replace with your actual predictor variables
#       4 y = df["SalePrice"]  # Replace with your actual response variable
# ----> 6 model = sm.OLS(y, sm.add_constant(X))  # Assuming you want to fit an ordinary least squares (OLS) model
#       7 results = model.fit()
#       9 # Calculate the residuals
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\regression\linear_model.py:922, in OLS.__init__(self, endog, exog, missing, hasconst, **kwargs)
#     919     msg = ("Weights are not supported in OLS and will be ignored"
#     920            "An exception will be raised in the next version.")
#     921     warnings.warn(msg, ValueWarning)
# --> 922 super(OLS, self).__init__(endog, exog, missing=missing,
# ...
